# %%
import os
import ee
import geemap
import math

# %%
# ee.Initialize()

# %%
period_of_interest = ee.Filter.date('2017-01-01', '2019-12-31')
inBands = ["B2","B3","B4","B5","B6","B7","B8","B8A","B11","B12"]
outBands = inBands.append(["NDVI","NDVI_STD","BSI"])
Area_Nice = ee.Geometry.Polygon(
        [
            [
                [6.560201, 43.526958],
                [6.560201, 44.371294],
                [7.51888, 44.371294],
                [7.51888, 43.526958],
                [6.560201, 43.526958],
            ]
        ]
    )

# %%
def maskS2clouds(image):
    qa = image.select('QA60')

    # Bits 10 and 11 are clouds and cirrus, respectively.
    cloudBitMask = 1 << 10 # 1024
    cirrusBitMask = 1 << 11 # 2048

    # Both flags should be set to zero, indicating clear conditions.
    mask = qa.bitwiseAnd(cloudBitMask).eq(0)
    mask = mask.bitwiseAnd(cirrusBitMask).eq(0)
    
    helper = image.updateMask(mask).divide(10000)
    ee.Image(helper.copyProperties(image, properties=["system:time_start"]))
    ee.Image(helper.copyProperties(image, properties=["CLOUD_COVERAGE_PERCENTAGE"]))

    return helper

# %%
s2 = (
    ee.ImageCollection('COPERNICUS/S2_SR') 
    .filterBounds(Area_Nice)
    .filter(period_of_interest)
    .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE',10)) 
    .map(maskS2clouds)
    .select(["B2","B3","B4","B5","B6","B7","B8","B8A","B11","B12"])# cannot use variable inBands!!
)
median = s2.median()

visParams = {
    'bands': ['B4', 'B3', 'B2'],#'B4', 'B3', 'B2'],
    'min': 0,
    'max': 0.3,
}

Map = geemap.Map()
Map.centerObject(Area_Nice)
Map.addLayer(median, visParams,'median')
Map
# Out:
# Map(center=[20, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(Togg…

# %%
def addNDVI(image):
    ndvi = image.normalizedDifference(['B8', 'B4']).rename('NDVI')
    return image.addBands(ndvi)

# %%
S2_NDVI = s2.map(addNDVI)

# %%
recent_S2 = ee.Image(S2_NDVI.sort('system:time_start', False).first())

# %%
print('Recent image: ', recent_S2)
# Out:
# Recent image:  ee.Image({
#   "functionInvocationValue": {
#     "functionName": "Collection.first",
#     "arguments": {
#       "collection": {
#         "functionInvocationValue": {
#           "functionName": "Collection.limit",
#           "arguments": {
#             "ascending": {
#               "constantValue": false
#             },
#             "collection": {
#               "functionInvocationValue": {
#                 "functionName": "Collection.map",
#                 "arguments": {
#                   "baseAlgorithm": {
#                     "functionDefinitionValue": {
#                       "argumentNames": [
#                         "_MAPPING_VAR_0_0"
#                       ],
#                       "body": {
#                         "functionInvocationValue": {
#                           "functionName": "Image.addBands",
#                           "arguments": {
#                             "dstImg": {
#                               "argumentReference": "_MAPPING_VAR_0_0"
#                             },
#                             "srcImg": {
#                               "functionInvocationValue": {
#                                 "functionName": "Image.rename",
#                                 "arguments": {
#                                   "input": {
#                                     "functionInvocationValue": {
#                                       "functionName": "Image.normalizedDifference",
#                                       "arguments": {
#                                         "bandNames": {
#                                           "constantValue": [
#                                             "B8",
#                                             "B4"
#                                           ]
#                                         },
#                                         "input": {
#                                           "argumentReference": "_MAPPING_VAR_0_0"
#                                         }
#                                       }
#                                     }
#                                   },
#                                   "names": {
#                                     "constantValue": [
#                                       "NDVI"
#                                     ]
#                                   }
#                                 }
#                               }
#                             }
#                           }
#                         }
#                       }
#                     }
#                   },
#                   "collection": {
#                     "functionInvocationValue": {
#                       "functionName": "Collection.map",
#                       "arguments": {
#                         "baseAlgorithm": {
#                           "functionDefinitionValue": {
#                             "argumentNames": [
#                               "_MAPPING_VAR_0_0"
#                             ],
#                             "body": {
#                               "functionInvocationValue": {
#                                 "functionName": "Image.select",
#                                 "arguments": {
#                                   "bandSelectors": {
#                                     "constantValue": [
#                                       "B2",
#                                       "B3",
#                                       "B4",
#                                       "B5",
#                                       "B6",
#                                       "B7",
#                                       "B8",
#                                       "B8A",
#                                       "B11",
#                                       "B12"
#                                     ]
#                                   },
#                                   "input": {
#                                     "argumentReference": "_MAPPING_VAR_0_0"
#                                   }
#                                 }
#                               }
#                             }
#                           }
#                         },
#                         "collection": {
#                           "functionInvocationValue": {
#                             "functionName": "Collection.map",
#                             "arguments": {
#                               "baseAlgorithm": {
#                                 "functionDefinitionValue": {
#                                   "argumentNames": [
#                                     "_MAPPING_VAR_0_0"
#                                   ],
#                                   "body": {
#                                     "functionInvocationValue": {
#                                       "functionName": "Image.divide",
#                                       "arguments": {
#                                         "image1": {
#                                           "functionInvocationValue": {
#                                             "functionName": "Image.updateMask",
#                                             "arguments": {
#                                               "image": {
#                                                 "argumentReference": "_MAPPING_VAR_0_0"
#                                               },
#                                               "mask": {
#                                                 "functionInvocationValue": {
#                                                   "functionName": "Image.eq",
#                                                   "arguments": {
#                                                     "image1": {
#                                                       "functionInvocationValue": {
#                                                         "functionName": "Image.bitwiseAnd",
#                                                         "arguments": {
#                                                           "image1": {
#                                                             "functionInvocationValue": {
#                                                               "functionName": "Image.eq",
#                                                               "arguments": {
#                                                                 "image1": {
#                                                                   "functionInvocationValue": {
#                                                                     "functionName": "Image.bitwiseAnd",
#                                                                     "arguments": {
#                                                                       "image1": {
#                                                                         "functionInvocationValue": {
#                                                                           "functionName": "Image.select",
#                                                                           "arguments": {
#                                                                             "bandSelectors": {
#                                                                               "constantValue": [
#                                                                                 "QA60"
#                                                                               ]
#                                                                             },
#                                                                             "input": {
#                                                                               "argumentReference": "_MAPPING_VAR_0_0"
#                                                                             }
#                                                                           }
#                                                                         }
#                                                                       },
#                                                                       "image2": {
#                                                                         "functionInvocationValue": {
#                                                                           "functionName": "Image.constant",
#                                                                           "arguments": {
#                                                                             "value": {
#                                                                               "constantValue": 1024
#                                                                             }
#                                                                           }
#                                                                         }
#                                                                       }
#                                                                     }
#                                                                   }
#                                                                 },
#                                                                 "image2": {
#                                                                   "functionInvocationValue": {
#                                                                     "functionName": "Image.constant",
#                                                                     "arguments": {
#                                                                       "value": {
#                                                                         "constantValue": 0
#                                                                       }
#                                                                     }
#                                                                   }
#                                                                 }
#                                                               }
#                                                             }
#                                                           },
#                                                           "image2": {
#                                                             "functionInvocationValue": {
#                                                               "functionName": "Image.constant",
#                                                               "arguments": {
#                                                                 "value": {
#                                                                   "constantValue": 2048
#                                                                 }
#                                                               }
#                                                             }
#                                                           }
#                                                         }
#                                                       }
#                                                     },
#                                                     "image2": {
#                                                       "functionInvocationValue": {
#                                                         "functionName": "Image.constant",
#                                                         "arguments": {
#                                                           "value": {
#                                                             "constantValue": 0
#                                                           }
#                                                         }
#                                                       }
#                                                     }
#                                                   }
#                                                 }
#                                               }
#                                             }
#                                           }
#                                         },
#                                         "image2": {
#                                           "functionInvocationValue": {
#                                             "functionName": "Image.constant",
#                                             "arguments": {
#                                               "value": {
#                                                 "constantValue": 10000
#                                               }
#                                             }
#                                           }
#                                         }
#                                       }
#                                     }
#                                   }
#                                 }
#                               },
#                               "collection": {
#                                 "functionInvocationValue": {
#                                   "functionName": "Collection.filter",
#                                   "arguments": {
#                                     "collection": {
#                                       "functionInvocationValue": {
#                                         "functionName": "Collection.filter",
#                                         "arguments": {
#                                           "collection": {
#                                             "functionInvocationValue": {
#                                               "functionName": "Collection.filter",
#                                               "arguments": {
#                                                 "collection": {
#                                                   "functionInvocationValue": {
#                                                     "functionName": "ImageCollection.load",
#                                                     "arguments": {
#                                                       "id": {
#                                                         "constantValue": "COPERNICUS/S2_SR"
#                                                       }
#                                                     }
#                                                   }
#                                                 },
#                                                 "filter": {
#                                                   "functionInvocationValue": {
#                                                     "functionName": "Filter.intersects",
#                                                     "arguments": {
#                                                       "leftField": {
#                                                         "constantValue": ".all"
#                                                       },
#                                                       "rightValue": {
#                                                         "functionInvocationValue": {
#                                                           "functionName": "Feature",
#                                                           "arguments": {
#                                                             "geometry": {
#                                                               "functionInvocationValue": {
#                                                                 "functionName": "GeometryConstructors.Polygon",
#                                                                 "arguments": {
#                                                                   "coordinates": {
#                                                                     "constantValue": [
#                                                                       [
#                                                                         [
#                                                                           6.560201,
#                                                                           43.526958
#                                                                         ],
#                                                                         [
#                                                                           6.560201,
#                                                                           44.371294
#                                                                         ],
#                                                                         [
#                                                                           7.51888,
#                                                                           44.371294
#                                                                         ],
#                                                                         [
#                                                                           7.51888,
#                                                                           43.526958
#                                                                         ],
#                                                                         [
#                                                                           6.560201,
#                                                                           43.526958
#                                                                         ]
#                                                                       ]
#                                                                     ]
#                                                                   },
#                                                                   "evenOdd": {
#                                                                     "constantValue": true
#                                                                   }
#                                                                 }
#                                                               }
#                                                             }
#                                                           }
#                                                         }
#                                                       }
#                                                     }
#                                                   }
#                                                 }
#                                               }
#                                             }
#                                           },
#                                           "filter": {
#                                             "functionInvocationValue": {
#                                               "functionName": "Filter.dateRangeContains",
#                                               "arguments": {
#                                                 "leftValue": {
#                                                   "functionInvocationValue": {
#                                                     "functionName": "DateRange",
#                                                     "arguments": {
#                                                       "end": {
#                                                         "constantValue": "2019-12-31"
#                                                       },
#                                                       "start": {
#                                                         "constantValue": "2017-01-01"
#                                                       }
#                                                     }
#                                                   }
#                                                 },
#                                                 "rightField": {
#                                                   "constantValue": "system:time_start"
#                                                 }
#                                               }
#                                             }
#                                           }
#                                         }
#                                       }
#                                     },
#                                     "filter": {
#                                       "functionInvocationValue": {
#                                         "functionName": "Filter.lessThan",
#                                         "arguments": {
#                                           "leftField": {
#                                             "constantValue": "CLOUDY_PIXEL_PERCENTAGE"
#                                           },
#                                           "rightValue": {
#                                             "constantValue": 10
#                                           }
#                                         }
#                                       }
#                                     }
#                                   }
#                                 }
#                               }
#                             }
#                           }
#                         }
#                       }
#                     }
#                   }
#                 }
#               }
#             },
#             "key": {
#               "constantValue": "system:time_start"
#             }
#           }
#         }
#       }
#     }
#   }
# })

# %%
NDVIpalette = ['FFFFFF', 'CE7E45', 'DF923D', 'F1B555', 'FCD163', '99B718', '74A901', '66A000', '529400', '3E8601', '207401', '056201', '004C00', '023B01', '012E01', '011D01', '011301']

# %%
Map.addLayer(recent_S2.select('NDVI'), {'palette': NDVIpalette}, 'Recent Sentinel NDVI')
Map.centerObject(Area_Nice)
Map
# Out:
# Map(bottom=24260.81817626953, center=[43.481551115425276, 7.354090568255632], controls=(WidgetControl(options=…

# %%
ten_day_S2 = S2_NDVI.sort('system:time_start', False).limit (10)
# print('Recent images: ', ten_day_S2)
Map.addLayer(ten_day_S2.select('NDVI').median(), {'palette': NDVIpalette}, '10 Day Median Sentinel NDVI')
Map
# Out:
# Map(bottom=767880.6363677979, center=[43.37752470242683, 6.729983407512182], controls=(WidgetControl(options=[…

# %% [markdown]
# # Chart

# %%
import pandas as pd
import altair as alt
import numpy as np
import folium
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [48], in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 import altair as alt
#       3 import numpy as np
#       4 import folium
#
# ModuleNotFoundError: No module named 'altair'

# %%
today = ee.Date(pd.to_datetime('today'))
date_range = ee.DateRange(today.advance(-20, 'years'), today)

# %%
# Define a function to transfer feature properties to a dictionary.
def fc_to_dict(fc):
    prop_names = fc.first().propertyNames()
    prop_lists = fc.reduceColumns(
      reducer=ee.Reducer.toList().repeat(prop_names.size()),
      selectors=prop_names).get('list')

    return ee.Dictionary.fromLists(prop_names, prop_lists)

# %%
ndvi = ee.ImageCollection('MODIS/006/MOD13A2').filterDate(date_range).select('NDVI').filterBounds(Area_Nice)

ndvi_dict = fc_to_dict(ndvi).getInfo()
ndvi_df = pd.DataFrame(ndvi_dict)
display(ndvi_df)
print(ndvi_df.dtypes)
# Out:
#      google:max_source_file_timestamp  system:asset_size system:band_names  \
# 0                       1528309196580         2792195822            [NDVI]
# 1                       1528309227932         2779335570            [NDVI]
# 2                       1528310673716         2781385101            [NDVI]
# 3                       1528309312684         2775264985            [NDVI]
# 4                       1528309218153         2801753874            [NDVI]
# ..                                ...                ...               ...
# 454                     1652526019000         2850848972            [NDVI]
# 455                     1653558187000         2838197115            [NDVI]
# 456                     1655022813000         2823228158            [NDVI]
# 457                     1656548348000         2802598825            [NDVI]
# 458                     1658098840000         2792103642            [NDVI]
#
#                                           system:bands  \
# 0    {'NDVI': {'data_type': {'type': 'PixelType', '...
# 1    {'NDVI': {'data_type': {'type': 'PixelType', '...
# 2    {'NDVI': {'data_type': {'type': 'PixelType', '...
# 3    {'NDVI': {'data_type': {'type': 'PixelType', '...
# 4    {'NDVI': {'data_type': {'type': 'PixelType', '...
# ..                                                 ...
# 454  {'NDVI': {'data_type': {'type': 'PixelType', '...
# 455  {'NDVI': {'data_type': {'type': 'PixelType', '...
# 456  {'NDVI': {'data_type': {'type': 'PixelType', '...
# 457  {'NDVI': {'data_type': {'type': 'PixelType', '...
# 458  {'NDVI': {'data_type': {'type': 'PixelType', '...
#
#                                       system:footprint  \
# 0    {'type': 'LinearRing', 'coordinates': [[-180, ...
# 1    {'type': 'LinearRing', 'coordinates': [[-180, ...
# 2    {'type': 'LinearRing', 'coordinates': [[-180, ...
# 3    {'type': 'LinearRing', 'coordinates': [[-180, ...
# 4    {'type': 'LinearRing', 'coordinates': [[-180, ...
# ..                                                 ...
# 454  {'type': 'LinearRing', 'coordinates': [[-180, ...
# 455  {'type': 'LinearRing', 'coordinates': [[-180, ...
# 456  {'type': 'LinearRing', 'coordinates': [[-180, ...
# 457  {'type': 'LinearRing', 'coordinates': [[-180, ...
# 458  {'type': 'LinearRing', 'coordinates': [[-180, ...
#
#                         system:id system:index  system:time_end  \
# 0    MODIS/006/MOD13A2/2002_07_28   2002_07_28    1029196800000
# 1    MODIS/006/MOD13A2/2002_08_13   2002_08_13    1030579200000
# 2    MODIS/006/MOD13A2/2002_08_29   2002_08_29    1031961600000
# 3    MODIS/006/MOD13A2/2002_09_14   2002_09_14    1033344000000
# 4    MODIS/006/MOD13A2/2002_09_30   2002_09_30    1034726400000
# ..                            ...          ...              ...
# 454  MODIS/006/MOD13A2/2022_04_23   2022_04_23    1652054400000
# 455  MODIS/006/MOD13A2/2022_05_09   2022_05_09    1653436800000
# 456  MODIS/006/MOD13A2/2022_05_25   2022_05_25    1654819200000
# 457  MODIS/006/MOD13A2/2022_06_10   2022_06_10    1656201600000
# 458  MODIS/006/MOD13A2/2022_06_26   2022_06_26    1657584000000
#
#      system:time_start  system:version
# 0        1027814400000    1.638765e+15
# 1        1029196800000    1.638765e+15
# 2        1030579200000    1.638765e+15
# 3        1031961600000    1.638765e+15
# 4        1033344000000    1.638765e+15
# ..                 ...             ...
# 454      1650672000000    1.652565e+15
# 455      1652054400000    1.653614e+15
# 456      1653436800000    1.655330e+15
# 457      1654819200000    1.656770e+15
# 458      1656201600000    1.658191e+15
#
# [459 rows x 10 columns]
# google:max_source_file_timestamp      int64
# system:asset_size                     int64
# system:band_names                    object
# system:bands                         object
# system:footprint                     object
# system:id                            object
# system:index                         object
# system:time_end                       int64
# system:time_start                     int64
# system:version                      float64
# dtype: object

# %%
ndvi_df.head(5)
# Out:
#    google:max_source_file_timestamp  system:asset_size system:band_names  \
# 0                     1528309196580         2792195822            [NDVI]
# 1                     1528309227932         2779335570            [NDVI]
# 2                     1528310673716         2781385101            [NDVI]
# 3                     1528309312684         2775264985            [NDVI]
# 4                     1528309218153         2801753874            [NDVI]
#
#                                         system:bands  \
# 0  {'NDVI': {'data_type': {'type': 'PixelType', '...
# 1  {'NDVI': {'data_type': {'type': 'PixelType', '...
# 2  {'NDVI': {'data_type': {'type': 'PixelType', '...
# 3  {'NDVI': {'data_type': {'type': 'PixelType', '...
# 4  {'NDVI': {'data_type': {'type': 'PixelType', '...
#
#                                     system:footprint  \
# 0  {'type': 'LinearRing', 'coordinates': [[-180, ...
# 1  {'type': 'LinearRing', 'coordinates': [[-180, ...
# 2  {'type': 'LinearRing', 'coordinates': [[-180, ...
# 3  {'type': 'LinearRing', 'coordinates': [[-180, ...
# 4  {'type': 'LinearRing', 'coordinates': [[-180, ...
#
#                       system:id system:index  system:time_end  \
# 0  MODIS/006/MOD13A2/2002_07_28   2002_07_28    1029196800000
# 1  MODIS/006/MOD13A2/2002_08_13   2002_08_13    1030579200000
# 2  MODIS/006/MOD13A2/2002_08_29   2002_08_29    1031961600000
# 3  MODIS/006/MOD13A2/2002_09_14   2002_09_14    1033344000000
# 4  MODIS/006/MOD13A2/2002_09_30   2002_09_30    1034726400000
#
#    system:time_start  system:version
# 0      1027814400000    1.638765e+15
# 1      1029196800000    1.638765e+15
# 2      1030579200000    1.638765e+15
# 3      1031961600000    1.638765e+15
# 4      1033344000000    1.638765e+15
